# %%
import os
import torch
import torchvision.transforms as T
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, SubsetRandomSampler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score, matthews_corrcoef
from transformers import BeitForImageClassification, BeitFeatureExtractor
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.cuda.amp import GradScaler, autocast

DATASET_PATH = r'C:\Users\sueda\OneDrive\Masaüstü\makina'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

feature_extractor = BeitFeatureExtractor.from_pretrained('microsoft/beit-base-patch16-224')

transform_train = T.Compose([
    T.Resize((224, 224)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.3),
    T.RandomRotation(degrees=30),
    T.RandomResizedCrop(size=(224, 224), scale=(0.6, 1.0)),
    T.ToTensor(),
    T.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

transform_test = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

dataset_train = datasets.ImageFolder(DATASET_PATH, transform=transform_train)
dataset_test = datasets.ImageFolder(DATASET_PATH, transform=transform_test)
class_names = dataset_train.classes
num_classes = len(class_names)
print(f'Classes: {class_names}')

def initialize_model(num_labels):
    model = BeitForImageClassification.from_pretrained(
        'microsoft/beit-base-patch16-224',
        num_labels=num_labels,
        ignore_mismatched_sizes=True
    )

    model.classifier.dropout = nn.Dropout(p=0.5)

    return model.to(device)

def train(model, dataloader, criterion, optimizer, scaler, gradient_accumulation_steps=4):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    
    optimizer.zero_grad()
    
    for step, (inputs, labels) in enumerate(dataloader):

        inputs, labels = inputs.to(device), labels.to(device)
        
        with autocast():
            outputs = model(inputs).logits  
            loss = criterion(outputs, labels)
            total_loss += loss.item()
        
        scaler.scale(loss).backward() 
        
        if (step + 1) % gradient_accumulation_steps == 0 or (step + 1) == len(dataloader):
            scaler.step(optimizer)  
            scaler.update()
            optimizer.zero_grad()  

        _, predicted = torch.max(outputs, 1)  
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy

def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    
    all_labels = []
    all_probs = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs).logits  
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1) 
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            all_probs.extend(torch.softmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy, np.array(all_labels), np.array(all_probs)

def calculate_metrics(y_true, y_pred, y_probs, num_classes, class_names):
    metrics = {}
    for i in range(num_classes):
        class_metrics = {}
        tp = ((y_true == i) & (y_pred == i)).sum()
        tn = ((y_true != i) & (y_pred != i)).sum()
        fp = ((y_true != i) & (y_pred == i)).sum()
        fn = ((y_true == i) & (y_pred != i)).sum()
        
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        mcc = matthews_corrcoef(y_true == i, y_pred == i)
        roc_auc = roc_auc_score(y_true == i, y_probs[:, i])
        
        class_metrics['Precision'] = precision
        class_metrics['Recall'] = recall
        class_metrics['F1-score'] = f1_score
        class_metrics['Accuracy'] = accuracy
        class_metrics['Sensitivity (Recall)'] = recall
        class_metrics['Specificity'] = specificity
        class_metrics['MCC'] = mcc
        class_metrics['AUC'] = roc_auc
        
        metrics[class_names[i]] = class_metrics
    
    return metrics

def k_fold_cross_validation(k, dataset_train, dataset_test, num_classes, class_names, batch_size=4, epochs=5, num_workers=4):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    fold_results = []

    all_indices = np.arange(len(dataset_train))
    all_labels = np.array([dataset_train.targets[i] for i in all_indices])

    overall_train_losses = np.zeros(epochs)
    overall_test_losses = np.zeros(epochs)
    overall_train_accuracies = np.zeros(epochs)
    overall_test_accuracies = np.zeros(epochs)

    all_fprs = {i: [] for i in range(num_classes)}
    all_tprs = {i: [] for i in range(num_classes)}
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_idx, test_idx) in enumerate(kf.split(all_indices, all_labels)):
        print(f'Fold {fold + 1}/{k}')
        
        train_sampler = SubsetRandomSampler(train_idx)
        test_sampler = SubsetRandomSampler(test_idx)
        
        train_loader = DataLoader(dataset_train, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
        test_loader = DataLoader(dataset_test, batch_size=batch_size, sampler=test_sampler, num_workers=num_workers)
        
        model = initialize_model(num_classes)
        criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
        optimizer = optim.AdamW(model.parameters(), lr=0.000005, weight_decay=0.01)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5)
        scaler = GradScaler()
        
        train_losses, test_losses = [], []
        train_accuracies, test_accuracies = [], []
        
        for epoch in range(epochs):
            train_loss, train_accuracy = train(model, train_loader, criterion, optimizer, scaler)
            test_loss, test_accuracy, _, _ = evaluate(model, test_loader, criterion)
            
            train_losses.append(train_loss)
            test_losses.append(test_loss)
            train_accuracies.append(train_accuracy)
            test_accuracies.append(test_accuracy)
            
            print(f'Epoch {epoch + 1}/{epochs}: '
                  f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
                  f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
            
            scheduler.step() 
        
        overall_train_losses += np.array(train_losses)
        overall_test_losses += np.array(test_losses)
        overall_train_accuracies += np.array(train_accuracies)
        overall_test_accuracies += np.array(test_accuracies)

        test_loss, test_accuracy, y_true, y_probs = evaluate(model, test_loader, criterion)
        
        fold_results.append({
            'train_losses': train_losses,
            'test_losses': test_losses,
            'train_accuracies': train_accuracies,
            'test_accuracies': test_accuracies
        })

        plt.figure(figsize=(8, 6))
        plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
        plt.plot(range(1, epochs + 1), test_losses, label='Test Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Fold {fold + 1}: Loss per Epoch')
        plt.legend()
        plt.show()
        
        y_pred = np.argmax(y_probs, axis=1)
        metrics = calculate_metrics(y_true, y_pred, y_probs, num_classes, class_names)

        for i in range(num_classes):
            fpr, tpr, _ = roc_curve(y_true == i, y_probs[:, i])
            all_fprs[i].append(np.interp(mean_fpr, fpr, tpr))
            all_fprs[i][-1][0] = 0.0
            all_tprs[i].append(tpr)
        fold_results.append({
            'train_losses': train_losses,
            'test_losses': test_losses,
            'train_accuracies': train_accuracies,
            'test_accuracies': test_accuracies,
            'metrics': metrics
        })
        
        for class_name, class_metrics in metrics.items():
            print(f'Fold {fold + 1} - Class {class_name} Metrics:')
            for metric, value in class_metrics.items():
                print(f'  {metric}: {value:.4f}')

    overall_train_losses /= k
    overall_test_losses /= k
    overall_train_accuracies /= k
    overall_test_accuracies /= k

    plt.figure(figsize=(8, 6))
    plt.plot(range(1, epochs + 1), overall_train_losses, label='Overall Train Loss')
    plt.plot(range(1, epochs + 1), overall_test_losses, label='Overall Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Overall Train vs Test Loss per Epoch')
    plt.legend()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.plot(range(1, epochs + 1), overall_train_accuracies, label='Overall Train Accuracy')
    plt.plot(range(1, epochs + 1), overall_test_accuracies, label='Overall Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Overall Train vs Test Accuracy per Epoch')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 8))
    for i in range(num_classes):
        mean_tpr = np.mean(all_fprs[i], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        plt.plot(mean_fpr, mean_tpr, label=f'Class {class_names[i]} (AUC = {mean_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

    return fold_results

results = k_fold_cross_validation(5, dataset_train, dataset_test, num_classes, class_names, batch_size=16, epochs=10, num_workers=4)
# Out:
# Using device: cuda
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\beit\feature_extraction_beit.py:28: FutureWarning: The class BeitFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use BeitImageProcessor instead.
#   warnings.warn(
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Classes: ['artnouveau', 'baroque', 'gothic', 'islamic']
# Fold 1/5
# Some weights of BeitForImageClassification were not initialized from the model checkpoint at microsoft/beit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 0.8958, Train Accuracy: 0.7150, Test Loss: 0.5660, Test Accuracy: 0.9081
# Epoch 2/15: Train Loss: 0.5509, Train Accuracy: 0.9204, Test Loss: 0.5046, Test Accuracy: 0.9351
# Epoch 3/15: Train Loss: 0.5062, Train Accuracy: 0.9425, Test Loss: 0.4729, Test Accuracy: 0.9523
# Epoch 4/15: Train Loss: 0.4897, Train Accuracy: 0.9470, Test Loss: 0.4676, Test Accuracy: 0.9565
# Epoch 5/15: Train Loss: 0.4802, Train Accuracy: 0.9549, Test Loss: 0.4648, Test Accuracy: 0.9593
# Epoch 6/15: Train Loss: 0.4795, Train Accuracy: 0.9553, Test Loss: 0.4633, Test Accuracy: 0.9599
# Epoch 10/15: Train Loss: 0.4826, Train Accuracy: 0.9551, Test Loss: 0.4593, Test Accuracy: 0.9655
# Epoch 11/15: Train Loss: 0.4828, Train Accuracy: 0.9549, Test Loss: 0.4593, Test Accuracy: 0.9655
# Epoch 12/15: Train Loss: 0.4820, Train Accuracy: 0.9560, Test Loss: 0.4592, Test Accuracy: 0.9655
# Epoch 13/15: Train Loss: 0.4840, Train Accuracy: 0.9534, Test Loss: 0.4592, Test Accuracy: 0.9655
# Epoch 14/15: Train Loss: 0.4821, Train Accuracy: 0.9565, Test Loss: 0.4592, Test Accuracy: 0.9655
# Epoch 15/15: Train Loss: 0.4829, Train Accuracy: 0.9536, Test Loss: 0.4592, Test Accuracy: 0.9655
# Fold 2 - Class artnouveau Metrics:
#   Precision: 0.9766
#   Recall: 0.9227
#   F1-score: 0.9489
#   Accuracy: 0.9751
#   Sensitivity (Recall): 0.9227
#   Specificity: 0.9926
#   MCC: 0.9331
#   AUC: 0.9968
# Fold 2 - Class baroque Metrics:
#   Precision: 0.9282
#   Recall: 0.9641
#   F1-score: 0.9458
#   Accuracy: 0.9724
#   Sensitivity (Recall): 0.9641
#   Specificity: 0.9751
#   MCC: 0.9276
#   AUC: 0.9942
# Fold 2 - Class gothic Metrics:
#   Precision: 0.9677
#   Recall: 0.9945
#   F1-score: 0.9809
#   Accuracy: 0.9903
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9890
#   MCC: 0.9746
#   AUC: 0.9997
# Fold 2 - Class islamic Metrics:
#   Precision: 0.9916
#   Recall: 0.9807
#   F1-score: 0.9861
#   Accuracy: 0.9931
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9972
#   MCC: 0.9815
#   AUC: 0.9997
# Fold 3/5
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BeitForImageClassification were not initialized from the model checkpoint at microsoft/beit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([4]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([4, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.0135, Train Accuracy: 0.6338, Test Loss: 0.6189, Test Accuracy: 0.8992
# Epoch 2/15: Train Loss: 0.5904, Train Accuracy: 0.9028, Test Loss: 0.5287, Test Accuracy: 0.9302
# Epoch 3/15: Train Loss: 0.5354, Train Accuracy: 0.9292, Test Loss: 0.5025, Test Accuracy: 0.9434
# Epoch 4/15: Train Loss: 0.5158, Train Accuracy: 0.9378, Test Loss: 0.4938, Test Accuracy: 0.9496
# Epoch 5/15: Train Loss: 0.5007, Train Accuracy: 0.9499, Test Loss: 0.4881, Test Accuracy: 0.9558
# Epoch 6/15: Train Loss: 0.5022, Train Accuracy: 0.9429, Test Loss: 0.4868, Test Accuracy: 0.9551
# Epoch 7/15: Train Loss: 0.4967, Train Accuracy: 0.9484, Test Loss: 0.4869, Test Accuracy: 0.9530
# Epoch 8/15: Train Loss: 0.4938, Train Accuracy: 0.9494, Test Loss: 0.4861, Test Accuracy: 0.9551
# Epoch 9/15: Train Loss: 0.4949, Train Accuracy: 0.9487, Test Loss: 0.4858, Test Accuracy: 0.9551
# Epoch 10/15: Train Loss: 0.4965, Train Accuracy: 0.9510, Test Loss: 0.4857, Test Accuracy: 0.9551
# Epoch 11/15: Train Loss: 0.4972, Train Accuracy: 0.9494, Test Loss: 0.4856, Test Accuracy: 0.9551
# Fold 5 - Class artnouveau Metrics:
#   Precision: 0.9456
#   Recall: 0.9116
#   F1-score: 0.9283
#   Accuracy: 0.9648
#   Sensitivity (Recall): 0.9116
#   Specificity: 0.9825
#   MCC: 0.9052
#   AUC: 0.9928
# Fold 5 - Class baroque Metrics:
#   Precision: 0.8886
#   Recall: 0.9475
#   F1-score: 0.9171
#   Accuracy: 0.9572
#   Sensitivity (Recall): 0.9475
#   Specificity: 0.9604
#   MCC: 0.8891
#   AUC: 0.9881
# Fold 5 - Class gothic Metrics:
#   Precision: 0.9669
#   Recall: 0.9696
#   F1-score: 0.9683
#   Accuracy: 0.9841
#   Sensitivity (Recall): 0.9696
#   Specificity: 0.9890
#   MCC: 0.9577
#   AUC: 0.9982
# Fold 5 - Class islamic Metrics:
#   Precision: 0.9857
#   Recall: 0.9530
#   F1-score: 0.9691
#   Accuracy: 0.9848
#   Sensitivity (Recall): 0.9530
#   Specificity: 0.9954
#   MCC: 0.9593
#   AUC: 0.9987

# %%
import pandas as pd

data = {
    'ArtNouveau': {
        'Precision': [0.9680, 0.9766, 0.9738, 0.9765, 0.9456],
        'Recall': [0.9199, 0.9227, 0.9227, 0.9199, 0.9116],
        'F1-score': [0.9433, 0.9489, 0.9475, 0.9474, 0.9283],
        'Accuracy': [0.9724, 0.9751, 0.9744, 0.9744, 0.9648],
        'Specificity': [0.9899, 0.9926, 0.9917, 0.9926, 0.9825],
        'MCC': [0.9256, 0.9331, 0.9312, 0.9312, 0.9052],
        'AUC': [0.9966, 0.9968, 0.9954, 0.9963, 0.9928]
    },
    'Baroque': {
        'Precision': [0.9160, 0.9282, 0.9101, 0.9132, 0.8886],
        'Recall': [0.9641, 0.9641, 0.9503, 0.9586, 0.9475],
        'F1-score': [0.9394, 0.9458, 0.9297, 0.9353, 0.9171],
        'Accuracy': [0.9689, 0.9724, 0.9641, 0.9669, 0.9572],
        'Specificity': [0.9705, 0.9751, 0.9687, 0.9696, 0.9604],
        'MCC': [0.9191, 0.9276, 0.9060, 0.9135, 0.8891],
        'AUC': [0.9948, 0.9942, 0.9865, 0.9901, 0.9881]
    },
    'Gothic': {
        'Precision': [0.9861, 0.9677, 0.9668, 0.9621, 0.9669],
        'Recall': [0.9834, 0.9945, 0.9641, 0.9807, 0.9696],
        'F1-score': [0.9848, 0.9809, 0.9654, 0.9713, 0.9683],
        'Accuracy': [0.9924, 0.9903, 0.9827, 0.9855, 0.9841],
        'Specificity': [0.9954, 0.9890, 0.9890, 0.9871, 0.9890],
        'MCC': [0.9797, 0.9746, 0.9539, 0.9617, 0.9577],
        'AUC': [0.9994, 0.9997, 0.9985, 0.9985, 0.9982]
    },
    'Islamic': {
        'Precision': [0.9807, 0.9916, 0.9727, 0.9888, 0.9857],
        'Recall': [0.9807, 0.9807, 0.9834, 0.9779, 0.9530],
        'F1-score': [0.9807, 0.9861, 0.9780, 0.9833, 0.9691],
        'Accuracy': [0.9903, 0.9931, 0.9890, 0.9917, 0.9848],
        'Specificity': [0.9936, 0.9972, 0.9908, 0.9963, 0.9954],
        'MCC': [0.9742, 0.9815, 0.9707, 0.9778, 0.9593],
        'AUC': [0.9993, 0.9997, 0.9985, 0.9994, 0.9987]
    }
}

averages = {metric: [] for metric in data['ArtNouveau']}
overall = {metric: [] for metric in data['ArtNouveau']}

for metric in data['ArtNouveau']:
    for class_name in data:
        avg = sum(data[class_name][metric]) / len(data[class_name][metric])
        averages[metric].append(avg)
    overall_avg = sum(averages[metric]) / len(averages[metric])
    overall[metric] = overall_avg

class_names = list(data.keys())
class_names.append('Overall')
metrics = list(data['ArtNouveau'].keys())

df_data = {class_name: [] for class_name in class_names}
for metric in metrics:
    for i, class_name in enumerate(class_names[:-1]):
        df_data[class_name].append(averages[metric][i])
    df_data['Overall'].append(overall[metric])

df = pd.DataFrame(df_data, index=metrics)

styled_df = df.style.set_table_styles(
    [{
        'selector': 'th',
        'props': [('font-size', '10pt'),
                  ('border', '1px solid black'),
                  ('text-align', 'center'),
                  ('background-color', '#333333'),
                  ('color', 'white')]
    }, {
        'selector': 'td',
        'props': [('font-size', '11pt'),
                  ('border', '1px solid black'),
                  ('text-align', 'center'),
                  ('background-color', '#444444'),
                  ('color', 'white')]
    }]
).set_properties(**{'text-align': 'center'})

styled_df
# Out:
# <style type="text/css">
# #T_6a8cb th {
#   font-size: 10pt;
#   border: 1px solid black;
#   text-align: center;
#   background-color: #333333;
#   color: white;
# }
# #T_6a8cb td {
#   font-size: 11pt;
#   border: 1px solid black;
#   text-align: center;
#   background-color: #444444;
#   color: white;
# }
# #T_6a8cb_row0_col0, #T_6a8cb_row0_col1, #T_6a8cb_row0_col2, #T_6a8cb_row0_col3, #T_6a8cb_row0_col4, #T_6a8cb_row1_col0, #T_6a8cb_row1_col1, #T_6a8cb_row1_col2, #T_6a8cb_row1_col3, #T_6a8cb_row1_col4, #T_6a8cb_row2_col0, #T_6a8cb_row2_col1, #T_6a8cb_row2_col2, #T_6a8cb_row2_col3, #T_6a8cb_row2_col4, #T_6a8cb_row3_col0, #T_6a8cb_row3_col1, #T_6a8cb_row3_col2, #T_6a8cb_row3_col3, #T_6a8cb_row3_col4, #T_6a8cb_row4_col0, #T_6a8cb_row4_col1, #T_6a8cb_row4_col2, #T_6a8cb_row4_col3, #T_6a8cb_row4_col4, #T_6a8cb_row5_col0, #T_6a8cb_row5_col1, #T_6a8cb_row5_col2, #T_6a8cb_row5_col3, #T_6a8cb_row5_col4, #T_6a8cb_row6_col0, #T_6a8cb_row6_col1, #T_6a8cb_row6_col2, #T_6a8cb_row6_col3, #T_6a8cb_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_6a8cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a8cb_level0_col0" class="col_heading level0 col0" >ArtNouveau</th>
#       <th id="T_6a8cb_level0_col1" class="col_heading level0 col1" >Baroque</th>
#       <th id="T_6a8cb_level0_col2" class="col_heading level0 col2" >Gothic</th>
#       <th id="T_6a8cb_level0_col3" class="col_heading level0 col3" >Islamic</th>
#       <th id="T_6a8cb_level0_col4" class="col_heading level0 col4" >Overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a8cb_level0_row0" class="row_heading level0 row0" >Precision</th>
#       <td id="T_6a8cb_row0_col0" class="data row0 col0" >0.968100</td>
#       <td id="T_6a8cb_row0_col1" class="data row0 col1" >0.911220</td>
#       <td id="T_6a8cb_row0_col2" class="data row0 col2" >0.969920</td>
#       <td id="T_6a8cb_row0_col3" class="data row0 col3" >0.983900</td>
#       <td id="T_6a8cb_row0_col4" class="data row0 col4" >0.958285</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row1" class="row_heading level0 row1" >Recall</th>
#       <td id="T_6a8cb_row1_col0" class="data row1 col0" >0.919360</td>
#       <td id="T_6a8cb_row1_col1" class="data row1 col1" >0.956920</td>
#       <td id="T_6a8cb_row1_col2" class="data row1 col2" >0.978460</td>
#       <td id="T_6a8cb_row1_col3" class="data row1 col3" >0.975140</td>
#       <td id="T_6a8cb_row1_col4" class="data row1 col4" >0.957470</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row2" class="row_heading level0 row2" >F1-score</th>
#       <td id="T_6a8cb_row2_col0" class="data row2 col0" >0.943080</td>
#       <td id="T_6a8cb_row2_col1" class="data row2 col1" >0.933460</td>
#       <td id="T_6a8cb_row2_col2" class="data row2 col2" >0.974140</td>
#       <td id="T_6a8cb_row2_col3" class="data row2 col3" >0.979440</td>
#       <td id="T_6a8cb_row2_col4" class="data row2 col4" >0.957530</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row3" class="row_heading level0 row3" >Accuracy</th>
#       <td id="T_6a8cb_row3_col0" class="data row3 col0" >0.972220</td>
#       <td id="T_6a8cb_row3_col1" class="data row3 col1" >0.965900</td>
#       <td id="T_6a8cb_row3_col2" class="data row3 col2" >0.987000</td>
#       <td id="T_6a8cb_row3_col3" class="data row3 col3" >0.989780</td>
#       <td id="T_6a8cb_row3_col4" class="data row3 col4" >0.978725</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row4" class="row_heading level0 row4" >Specificity</th>
#       <td id="T_6a8cb_row4_col0" class="data row4 col0" >0.989860</td>
#       <td id="T_6a8cb_row4_col1" class="data row4 col1" >0.968860</td>
#       <td id="T_6a8cb_row4_col2" class="data row4 col2" >0.989900</td>
#       <td id="T_6a8cb_row4_col3" class="data row4 col3" >0.994660</td>
#       <td id="T_6a8cb_row4_col4" class="data row4 col4" >0.985820</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row5" class="row_heading level0 row5" >MCC</th>
#       <td id="T_6a8cb_row5_col0" class="data row5 col0" >0.925260</td>
#       <td id="T_6a8cb_row5_col1" class="data row5 col1" >0.911060</td>
#       <td id="T_6a8cb_row5_col2" class="data row5 col2" >0.965520</td>
#       <td id="T_6a8cb_row5_col3" class="data row5 col3" >0.972700</td>
#       <td id="T_6a8cb_row5_col4" class="data row5 col4" >0.943635</td>
#     </tr>
#     <tr>
#       <th id="T_6a8cb_level0_row6" class="row_heading level0 row6" >AUC</th>
#       <td id="T_6a8cb_row6_col0" class="data row6 col0" >0.995580</td>
#       <td id="T_6a8cb_row6_col1" class="data row6 col1" >0.990740</td>
#       <td id="T_6a8cb_row6_col2" class="data row6 col2" >0.998860</td>
#       <td id="T_6a8cb_row6_col3" class="data row6 col3" >0.999120</td>
#       <td id="T_6a8cb_row6_col4" class="data row6 col4" >0.996075</td>
#     </tr>
#   </tbody>
# </table>
