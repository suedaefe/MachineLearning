# %%
import os
import torch
import torchvision.transforms as T
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, SubsetRandomSampler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, matthews_corrcoef
from transformers import DeiTForImageClassification, DeiTFeatureExtractor
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.cuda.amp import GradScaler, autocast

DATASET_PATH = r'C:\Users\sueda\OneDrive\Masaüstü\makina'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

feature_extractor = DeiTFeatureExtractor.from_pretrained('facebook/deit-base-distilled-patch16-224')

transform_train = T.Compose([
    T.Resize((224, 224)),
    T.RandomHorizontalFlip(),
    T.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.3),
    T.RandomRotation(degrees=30),
    T.RandomResizedCrop(size=(224, 224), scale=(0.6, 1.0)),
    T.ToTensor(),
    T.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

transform_test = T.Compose([
    T.Resize((224, 224)),
    T.ToTensor(),
    T.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
])

dataset_train = datasets.ImageFolder(DATASET_PATH, transform=transform_train)
dataset_test = datasets.ImageFolder(DATASET_PATH, transform=transform_test)
class_names = dataset_train.classes
num_classes = len(class_names)
print(f'Classes: {class_names}')

def initialize_model(num_labels):
    model = DeiTForImageClassification.from_pretrained(
        'facebook/deit-base-distilled-patch16-224',
        num_labels=num_labels,
        ignore_mismatched_sizes=True
    )

    model.classifier.dropout = nn.Dropout(p=0.3)

    return model.to(device)

def train(model, dataloader, criterion, optimizer, scaler, gradient_accumulation_steps=4):
    model.train()
    total_loss = 0
    correct = 0
    total = 0
    
    optimizer.zero_grad()  
    
    for step, (inputs, labels) in enumerate(dataloader):
        inputs, labels = inputs.to(device), labels.to(device)
        
        with autocast():
            outputs = model(inputs).logits  
            loss = criterion(outputs, labels)
            total_loss += loss.item()
        
        scaler.scale(loss).backward()  
        
        if (step + 1) % gradient_accumulation_steps == 0 or (step + 1) == len(dataloader):
            scaler.step(optimizer) 
            scaler.update()
            optimizer.zero_grad()  

        _, predicted = torch.max(outputs, 1)  
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy

def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0
    
    all_labels = []
    all_probs = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs).logits  
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1) 
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            
            all_probs.extend(torch.softmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    avg_loss = total_loss / len(dataloader)
    accuracy = correct / total
    return avg_loss, accuracy, np.array(all_labels), np.array(all_probs)


def calculate_metrics(y_true, y_pred, y_probs, num_classes, class_names):
    metrics = {}
    for i in range(num_classes):
        class_metrics = {}
        tp = ((y_true == i) & (y_pred == i)).sum()
        tn = ((y_true != i) & (y_pred != i)).sum()
        fp = ((y_true != i) & (y_pred == i)).sum()
        fn = ((y_true == i) & (y_pred != i)).sum()
        
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        accuracy = (tp + tn) / (tp + tn + fp + fn)
        mcc = matthews_corrcoef(y_true == i, y_pred == i)
        roc_auc = roc_auc_score(y_true == i, y_probs[:, i])
        
        class_metrics['Precision'] = precision
        class_metrics['Recall'] = recall
        class_metrics['F1-score'] = f1_score
        class_metrics['Accuracy'] = accuracy
        class_metrics['Sensitivity (Recall)'] = recall
        class_metrics['Specificity'] = specificity
        class_metrics['MCC'] = mcc
        class_metrics['AUC'] = roc_auc
        
        metrics[class_names[i]] = class_metrics
    
    return metrics


def k_fold_cross_validation(k, dataset_train, dataset_test, num_classes, class_names, batch_size, epochs, num_workers):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
    fold_results = []

    all_indices = np.arange(len(dataset_train))
    all_labels = np.array([dataset_train.targets[i] for i in all_indices])

    overall_train_losses = np.zeros(epochs)
    overall_test_losses = np.zeros(epochs)
    overall_train_accuracies = np.zeros(epochs)
    overall_test_accuracies = np.zeros(epochs)

    all_fprs = {i: [] for i in range(num_classes)}
    all_tprs = {i: [] for i in range(num_classes)}
    mean_fpr = np.linspace(0, 1, 100)

    for fold, (train_idx, test_idx) in enumerate(kf.split(all_indices, all_labels)):
        print(f'Fold {fold + 1}/{k}')
        
        train_sampler = SubsetRandomSampler(train_idx)
        test_sampler = SubsetRandomSampler(test_idx)
        
        train_loader = DataLoader(dataset_train, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
        test_loader = DataLoader(dataset_test, batch_size=batch_size, sampler=test_sampler, num_workers=num_workers)
        
        model = initialize_model(num_classes)
        criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
        optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.01)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.5)
        scaler = GradScaler()
        
        train_losses, test_losses = [], []
        train_accuracies, test_accuracies = [], []
        
        for epoch in range(epochs):
            train_loss, train_accuracy = train(model, train_loader, criterion, optimizer, scaler)
            test_loss, test_accuracy, _, _ = evaluate(model, test_loader, criterion)
            
            train_losses.append(train_loss)
            test_losses.append(test_loss)
            train_accuracies.append(train_accuracy)
            test_accuracies.append(test_accuracy)
            
            print(f'Epoch {epoch + 1}/{epochs}: '
                  f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
                  f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
            
            scheduler.step() 
        
        overall_train_losses += np.array(train_losses)
        overall_test_losses += np.array(test_losses)
        overall_train_accuracies += np.array(train_accuracies)
        overall_test_accuracies += np.array(test_accuracies)

        test_loss, test_accuracy, y_true, y_probs = evaluate(model, test_loader, criterion)

        for i in range(num_classes):
            fpr, tpr, _ = roc_curve(y_true == i, y_probs[:, i])
            all_fprs[i].append(np.interp(mean_fpr, fpr, tpr))
            all_fprs[i][-1][0] = 0.0
            all_tprs[i].append(tpr)
        
        fold_results.append({
            'train_losses': train_losses,
            'test_losses': test_losses,
            'train_accuracies': train_accuracies,
            'test_accuracies': test_accuracies
        })

        plt.figure(figsize=(8, 6))
        plt.plot(range(1, epochs + 1), train_losses, label='Train Loss')
        plt.plot(range(1, epochs + 1), test_losses, label='Test Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Fold {fold + 1}: Loss per Epoch')
        plt.legend()
        plt.show()

        y_pred = np.argmax(y_probs, axis=1)
        metrics = calculate_metrics(y_true, y_pred, y_probs, num_classes, class_names)
        fold_results.append({
            'train_losses': train_losses,
            'test_losses': test_losses,
            'train_accuracies': train_accuracies,
            'test_accuracies': test_accuracies,
            'metrics': metrics
        })
        
        for class_name, class_metrics in metrics.items():
            print(f'Fold {fold + 1} - Class {class_name} Metrics:')
            for metric, value in class_metrics.items():
                print(f'  {metric}: {value:.4f}')
    
    overall_train_losses /= k
    overall_test_losses /= k
    overall_train_accuracies /= k
    overall_test_accuracies /= k

    plt.figure(figsize=(8, 6))
    plt.plot(range(1, epochs + 1), overall_train_losses, label='Overall Train Loss')
    plt.plot(range(1, epochs + 1), overall_test_losses, label='Overall Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Overall Train vs Test Loss per Epoch')
    plt.legend()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.plot(range(1, epochs + 1), overall_train_accuracies, label='Overall Train Accuracy')
    plt.plot(range(1, epochs + 1), overall_test_accuracies, label='Overall Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Overall Train vs Test Accuracy per Epoch')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 8))
    for i in range(num_classes):
        mean_tpr = np.mean(all_fprs[i], axis=0)
        mean_tpr[-1] = 1.0
        mean_auc = auc(mean_fpr, mean_tpr)
        plt.plot(mean_fpr, mean_tpr, label=f'Class {class_names[i]} (AUC = {mean_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Average ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

    return fold_results

results = k_fold_cross_validation(5, dataset_train, dataset_test, num_classes, class_names, batch_size=8, epochs=15, num_workers=4)
# Out:
# Using device: cuda
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\deit\feature_extraction_deit.py:28: FutureWarning: The class DeiTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use DeiTImageProcessor instead.
#   warnings.warn(
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Classes: ['artnouveau', 'baroque', 'gothic', 'islamic']
# Fold 1/5
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.3212, Train Accuracy: 0.3943, Test Loss: 1.0018, Test Accuracy: 0.6561
# Epoch 2/15: Train Loss: 0.8176, Train Accuracy: 0.7524, Test Loss: 0.6208, Test Accuracy: 0.8584
# Epoch 3/15: Train Loss: 0.5308, Train Accuracy: 0.9097, Test Loss: 0.4608, Test Accuracy: 0.9544
# Epoch 4/15: Train Loss: 0.4125, Train Accuracy: 0.9734, Test Loss: 0.4267, Test Accuracy: 0.9593
# Epoch 5/15: Train Loss: 0.3802, Train Accuracy: 0.9872, Test Loss: 0.3964, Test Accuracy: 0.9786
# Epoch 6/15: Train Loss: 0.3666, Train Accuracy: 0.9926, Test Loss: 0.3939, Test Accuracy: 0.9772
# Epoch 7/15: Train Loss: 0.3641, Train Accuracy: 0.9938, Test Loss: 0.3927, Test Accuracy: 0.9779
# Epoch 8/15: Train Loss: 0.3628, Train Accuracy: 0.9950, Test Loss: 0.3917, Test Accuracy: 0.9772
# Epoch 9/15: Train Loss: 0.3594, Train Accuracy: 0.9959, Test Loss: 0.3888, Test Accuracy: 0.9793
# Epoch 10/15: Train Loss: 0.3589, Train Accuracy: 0.9972, Test Loss: 0.3882, Test Accuracy: 0.9807
# Epoch 11/15: Train Loss: 0.3597, Train Accuracy: 0.9964, Test Loss: 0.3876, Test Accuracy: 0.9807
# Epoch 12/15: Train Loss: 0.3581, Train Accuracy: 0.9972, Test Loss: 0.3875, Test Accuracy: 0.9807
# Epoch 13/15: Train Loss: 0.3591, Train Accuracy: 0.9965, Test Loss: 0.3875, Test Accuracy: 0.9807
# Epoch 14/15: Train Loss: 0.3604, Train Accuracy: 0.9950, Test Loss: 0.3874, Test Accuracy: 0.9807
# Epoch 15/15: Train Loss: 0.3598, Train Accuracy: 0.9965, Test Loss: 0.3873, Test Accuracy: 0.9807
# Fold 1 - Class artnouveau Metrics:
#   Precision: 0.9753
#   Recall: 0.9807
#   F1-score: 0.9780
#   Accuracy: 0.9890
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9917
#   MCC: 0.9706
#   AUC: 0.9988
# Fold 1 - Class baroque Metrics:
#   Precision: 0.9802
#   Recall: 0.9558
#   F1-score: 0.9678
#   Accuracy: 0.9841
#   Sensitivity (Recall): 0.9558
#   Specificity: 0.9936
#   MCC: 0.9574
#   AUC: 0.9983
# Fold 1 - Class gothic Metrics:
#   Precision: 0.9836
#   Recall: 0.9945
#   F1-score: 0.9890
#   Accuracy: 0.9945
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9945
#   MCC: 0.9853
#   AUC: 0.9989
# Fold 1 - Class islamic Metrics:
#   Precision: 0.9836
#   Recall: 0.9917
#   F1-score: 0.9876
#   Accuracy: 0.9938
#   Sensitivity (Recall): 0.9917
#   Specificity: 0.9945
#   MCC: 0.9835
#   AUC: 0.9998
# Fold 2/5
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.3111, Train Accuracy: 0.4076, Test Loss: 1.0883, Test Accuracy: 0.5946
# Epoch 2/15: Train Loss: 0.9087, Train Accuracy: 0.6979, Test Loss: 0.6783, Test Accuracy: 0.8294
# Epoch 3/15: Train Loss: 0.6065, Train Accuracy: 0.8719, Test Loss: 0.4999, Test Accuracy: 0.9233
# Epoch 4/15: Train Loss: 0.4637, Train Accuracy: 0.9473, Test Loss: 0.4408, Test Accuracy: 0.9593
# Epoch 5/15: Train Loss: 0.4098, Train Accuracy: 0.9720, Test Loss: 0.4076, Test Accuracy: 0.9744
# Epoch 6/15: Train Loss: 0.3878, Train Accuracy: 0.9824, Test Loss: 0.3974, Test Accuracy: 0.9807
# Epoch 7/15: Train Loss: 0.3729, Train Accuracy: 0.9917, Test Loss: 0.3894, Test Accuracy: 0.9814
# Epoch 8/15: Train Loss: 0.3687, Train Accuracy: 0.9926, Test Loss: 0.3839, Test Accuracy: 0.9855
# Epoch 9/15: Train Loss: 0.3674, Train Accuracy: 0.9936, Test Loss: 0.3838, Test Accuracy: 0.9862
# Epoch 10/15: Train Loss: 0.3691, Train Accuracy: 0.9922, Test Loss: 0.3837, Test Accuracy: 0.9862
# Epoch 11/15: Train Loss: 0.3671, Train Accuracy: 0.9924, Test Loss: 0.3837, Test Accuracy: 0.9855
# Epoch 12/15: Train Loss: 0.3655, Train Accuracy: 0.9941, Test Loss: 0.3837, Test Accuracy: 0.9855
# Epoch 13/15: Train Loss: 0.3689, Train Accuracy: 0.9921, Test Loss: 0.3837, Test Accuracy: 0.9855
# Epoch 14/15: Train Loss: 0.3667, Train Accuracy: 0.9938, Test Loss: 0.3837, Test Accuracy: 0.9855
# Epoch 15/15: Train Loss: 0.3671, Train Accuracy: 0.9943, Test Loss: 0.3838, Test Accuracy: 0.9855
# Fold 2 - Class artnouveau Metrics:
#   Precision: 0.9916
#   Recall: 0.9779
#   F1-score: 0.9847
#   Accuracy: 0.9924
#   Sensitivity (Recall): 0.9779
#   Specificity: 0.9972
#   MCC: 0.9797
#   AUC: 0.9970
# Fold 2 - Class baroque Metrics:
#   Precision: 0.9834
#   Recall: 0.9807
#   F1-score: 0.9820
#   Accuracy: 0.9910
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9945
#   MCC: 0.9760
#   AUC: 0.9995
# Fold 2 - Class gothic Metrics:
#   Precision: 0.9756
#   Recall: 0.9945
#   F1-score: 0.9850
#   Accuracy: 0.9924
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9917
#   MCC: 0.9800
#   AUC: 0.9999
# Fold 2 - Class islamic Metrics:
#   Precision: 0.9917
#   Recall: 0.9890
#   F1-score: 0.9903
#   Accuracy: 0.9952
#   Sensitivity (Recall): 0.9890
#   Specificity: 0.9972
#   MCC: 0.9871
#   AUC: 0.9999
# Fold 3/5
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.3094, Train Accuracy: 0.4018, Test Loss: 1.1229, Test Accuracy: 0.5580
# Epoch 2/15: Train Loss: 0.8242, Train Accuracy: 0.7483, Test Loss: 0.6513, Test Accuracy: 0.8660
# Epoch 3/15: Train Loss: 0.5256, Train Accuracy: 0.9159, Test Loss: 0.4880, Test Accuracy: 0.9372
# Epoch 4/15: Train Loss: 0.4275, Train Accuracy: 0.9639, Test Loss: 0.4709, Test Accuracy: 0.9420
# Epoch 5/15: Train Loss: 0.3821, Train Accuracy: 0.9865, Test Loss: 0.3943, Test Accuracy: 0.9800
# Epoch 6/15: Train Loss: 0.3699, Train Accuracy: 0.9912, Test Loss: 0.3923, Test Accuracy: 0.9800
# Epoch 7/15: Train Loss: 0.3675, Train Accuracy: 0.9926, Test Loss: 0.3899, Test Accuracy: 0.9820
# Epoch 8/15: Train Loss: 0.3648, Train Accuracy: 0.9948, Test Loss: 0.3881, Test Accuracy: 0.9834
# Epoch 9/15: Train Loss: 0.3611, Train Accuracy: 0.9965, Test Loss: 0.3848, Test Accuracy: 0.9841
# Epoch 10/15: Train Loss: 0.3594, Train Accuracy: 0.9967, Test Loss: 0.3843, Test Accuracy: 0.9841
# Epoch 11/15: Train Loss: 0.3616, Train Accuracy: 0.9957, Test Loss: 0.3841, Test Accuracy: 0.9834
# Epoch 12/15: Train Loss: 0.3597, Train Accuracy: 0.9969, Test Loss: 0.3839, Test Accuracy: 0.9834
# Epoch 13/15: Train Loss: 0.3610, Train Accuracy: 0.9959, Test Loss: 0.3838, Test Accuracy: 0.9841
# Epoch 14/15: Train Loss: 0.3605, Train Accuracy: 0.9965, Test Loss: 0.3839, Test Accuracy: 0.9841
# Epoch 15/15: Train Loss: 0.3618, Train Accuracy: 0.9962, Test Loss: 0.3839, Test Accuracy: 0.9841
# Fold 3 - Class artnouveau Metrics:
#   Precision: 0.9834
#   Recall: 0.9807
#   F1-score: 0.9820
#   Accuracy: 0.9910
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9945
#   MCC: 0.9760
#   AUC: 0.9994
# Fold 3 - Class baroque Metrics:
#   Precision: 0.9805
#   Recall: 0.9724
#   F1-score: 0.9764
#   Accuracy: 0.9883
#   Sensitivity (Recall): 0.9724
#   Specificity: 0.9936
#   MCC: 0.9686
#   AUC: 0.9993
# Fold 3 - Class gothic Metrics:
#   Precision: 0.9836
#   Recall: 0.9945
#   F1-score: 0.9890
#   Accuracy: 0.9945
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9945
#   MCC: 0.9853
#   AUC: 0.9998
# Fold 3 - Class islamic Metrics:
#   Precision: 0.9890
#   Recall: 0.9890
#   F1-score: 0.9890
#   Accuracy: 0.9945
#   Sensitivity (Recall): 0.9890
#   Specificity: 0.9963
#   MCC: 0.9853
#   AUC: 0.9999
# Fold 4/5
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.3771, Train Accuracy: 0.3211, Test Loss: 1.2884, Test Accuracy: 0.4047
# Epoch 2/15: Train Loss: 1.1155, Train Accuracy: 0.5656, Test Loss: 1.0151, Test Accuracy: 0.6443
# Epoch 3/15: Train Loss: 0.7640, Train Accuracy: 0.7861, Test Loss: 0.6300, Test Accuracy: 0.8681
# Epoch 4/15: Train Loss: 0.5070, Train Accuracy: 0.9249, Test Loss: 0.4497, Test Accuracy: 0.9503
# Epoch 5/15: Train Loss: 0.4184, Train Accuracy: 0.9665, Test Loss: 0.4091, Test Accuracy: 0.9717
# Epoch 6/15: Train Loss: 0.3887, Train Accuracy: 0.9836, Test Loss: 0.3953, Test Accuracy: 0.9814
# Epoch 7/15: Train Loss: 0.3777, Train Accuracy: 0.9874, Test Loss: 0.4032, Test Accuracy: 0.9738
# Epoch 8/15: Train Loss: 0.3710, Train Accuracy: 0.9924, Test Loss: 0.3956, Test Accuracy: 0.9800
# Epoch 9/15: Train Loss: 0.3683, Train Accuracy: 0.9938, Test Loss: 0.3925, Test Accuracy: 0.9807
# Epoch 10/15: Train Loss: 0.3671, Train Accuracy: 0.9948, Test Loss: 0.3916, Test Accuracy: 0.9807
# Epoch 11/15: Train Loss: 0.3660, Train Accuracy: 0.9941, Test Loss: 0.3906, Test Accuracy: 0.9814
# Epoch 12/15: Train Loss: 0.3666, Train Accuracy: 0.9940, Test Loss: 0.3909, Test Accuracy: 0.9800
# Epoch 13/15: Train Loss: 0.3640, Train Accuracy: 0.9952, Test Loss: 0.3913, Test Accuracy: 0.9800
# Epoch 14/15: Train Loss: 0.3663, Train Accuracy: 0.9948, Test Loss: 0.3912, Test Accuracy: 0.9800
# Epoch 15/15: Train Loss: 0.3659, Train Accuracy: 0.9953, Test Loss: 0.3911, Test Accuracy: 0.9807
# Fold 4 - Class artnouveau Metrics:
#   Precision: 0.9889
#   Recall: 0.9807
#   F1-score: 0.9847
#   Accuracy: 0.9924
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9963
#   MCC: 0.9797
#   AUC: 0.9995
# Fold 4 - Class baroque Metrics:
#   Precision: 0.9777
#   Recall: 0.9669
#   F1-score: 0.9722
#   Accuracy: 0.9862
#   Sensitivity (Recall): 0.9669
#   Specificity: 0.9926
#   MCC: 0.9631
#   AUC: 0.9984
# Fold 4 - Class gothic Metrics:
#   Precision: 0.9602
#   Recall: 1.0000
#   F1-score: 0.9797
#   Accuracy: 0.9896
#   Sensitivity (Recall): 1.0000
#   Specificity: 0.9862
#   MCC: 0.9731
#   AUC: 0.9990
# Fold 4 - Class islamic Metrics:
#   Precision: 0.9972
#   Recall: 0.9751
#   F1-score: 0.9860
#   Accuracy: 0.9931
#   Sensitivity (Recall): 0.9751
#   Specificity: 0.9991
#   MCC: 0.9816
#   AUC: 0.9999
# Fold 5/5
# c:\Users\sueda\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of DeiTForImageClassification were not initialized from the model checkpoint at facebook/deit-base-distilled-patch16-224 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/15: Train Loss: 1.3320, Train Accuracy: 0.3914, Test Loss: 1.0477, Test Accuracy: 0.6236
# Epoch 2/15: Train Loss: 0.8523, Train Accuracy: 0.7298, Test Loss: 0.6546, Test Accuracy: 0.8488
# Epoch 3/15: Train Loss: 0.5226, Train Accuracy: 0.9173, Test Loss: 0.4832, Test Accuracy: 0.9385
# Epoch 4/15: Train Loss: 0.4107, Train Accuracy: 0.9713, Test Loss: 0.4551, Test Accuracy: 0.9441
# Epoch 5/15: Train Loss: 0.3761, Train Accuracy: 0.9890, Test Loss: 0.3902, Test Accuracy: 0.9814
# Epoch 6/15: Train Loss: 0.3648, Train Accuracy: 0.9934, Test Loss: 0.4001, Test Accuracy: 0.9731
# Epoch 7/15: Train Loss: 0.3599, Train Accuracy: 0.9957, Test Loss: 0.3879, Test Accuracy: 0.9793
# Epoch 8/15: Train Loss: 0.3579, Train Accuracy: 0.9974, Test Loss: 0.3817, Test Accuracy: 0.9814
# Epoch 9/15: Train Loss: 0.3571, Train Accuracy: 0.9976, Test Loss: 0.3839, Test Accuracy: 0.9820
# Epoch 10/15: Train Loss: 0.3587, Train Accuracy: 0.9955, Test Loss: 0.3808, Test Accuracy: 0.9834
# Epoch 11/15: Train Loss: 0.3584, Train Accuracy: 0.9964, Test Loss: 0.3801, Test Accuracy: 0.9834
# Epoch 12/15: Train Loss: 0.3593, Train Accuracy: 0.9959, Test Loss: 0.3802, Test Accuracy: 0.9834
# Epoch 13/15: Train Loss: 0.3579, Train Accuracy: 0.9965, Test Loss: 0.3800, Test Accuracy: 0.9834
# Epoch 14/15: Train Loss: 0.3565, Train Accuracy: 0.9974, Test Loss: 0.3799, Test Accuracy: 0.9834
# Epoch 15/15: Train Loss: 0.3557, Train Accuracy: 0.9978, Test Loss: 0.3798, Test Accuracy: 0.9834
# Fold 5 - Class artnouveau Metrics:
#   Precision: 0.9756
#   Recall: 0.9945
#   F1-score: 0.9850
#   Accuracy: 0.9924
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9917
#   MCC: 0.9800
#   AUC: 0.9991
# Fold 5 - Class baroque Metrics:
#   Precision: 0.9831
#   Recall: 0.9641
#   F1-score: 0.9735
#   Accuracy: 0.9869
#   Sensitivity (Recall): 0.9641
#   Specificity: 0.9945
#   MCC: 0.9649
#   AUC: 0.9988
# Fold 5 - Class gothic Metrics:
#   Precision: 0.9783
#   Recall: 0.9945
#   F1-score: 0.9863
#   Accuracy: 0.9931
#   Sensitivity (Recall): 0.9945
#   Specificity: 0.9926
#   MCC: 0.9817
#   AUC: 0.9999
# Fold 5 - Class islamic Metrics:
#   Precision: 0.9972
#   Recall: 0.9807
#   F1-score: 0.9889
#   Accuracy: 0.9945
#   Sensitivity (Recall): 0.9807
#   Specificity: 0.9991
#   MCC: 0.9852
#   AUC: 0.9994

# %%
import pandas as pd

data = {
    'ArtNouveau': {
        'Precision': [0.9753, 0.9916, 0.9834, 0.9889, 0.9756],
        'Recall': [0.9807, 0.9779, 0.9807, 0.9807, 0.9945],
        'F1-score': [0.9780, 0.9847, 0.9820, 0.9847, 0.9850],
        'Accuracy': [0.9890, 0.9924, 0.9910, 0.9924, 0.9924],
        'Specificity': [0.9917, 0.9972, 0.9945, 0.9963, 0.9917],
        'MCC': [0.9706, 0.9797, 0.9760, 0.9797, 0.9800],
        'AUC': [0.9988, 0.9970, 0.9994, 0.9995, 0.9991]
    },
    'Baroque': {
        'Precision': [0.9802, 0.9834, 0.9805, 0.9777, 0.9831],
        'Recall': [0.9558, 0.9807, 0.9724, 0.9669, 0.9641],
        'F1-score': [0.9678, 0.9820, 0.9764, 0.9722, 0.9735],
        'Accuracy': [0.9841, 0.9910, 0.9883, 0.9862, 0.9869],
        'Specificity': [0.9936, 0.9945, 0.9936, 0.9926, 0.9945],
        'MCC': [0.9574, 0.9760, 0.9686, 0.9631, 0.9649],
        'AUC': [0.9983, 0.9995, 0.9993, 0.9984, 0.9988]
    },
    'Gothic': {
        'Precision': [0.9836, 0.9756, 0.9836, 0.9602, 0.9783],
        'Recall': [0.9945, 0.9945, 0.9945, 1.0000, 0.9945],
        'F1-score': [0.9890, 0.9850, 0.9890, 0.9797, 0.9863],
        'Accuracy': [0.9945, 0.9924, 0.9945, 0.9896, 0.9931],
        'Specificity': [0.9945, 0.9917, 0.9945, 0.9862, 0.9926],
        'MCC': [0.9853, 0.9800, 0.9853, 0.9731, 0.9817],
        'AUC': [0.9989, 0.9999, 0.9998, 0.9990, 0.9999]
    },
    'Islamic': {
        'Precision': [0.9836, 0.9917, 0.9890, 0.9972, 0.9972],
        'Recall': [0.9917, 0.9890, 0.9890, 0.9751, 0.9807],
        'F1-score': [0.9876, 0.9903, 0.9890, 0.9860, 0.9889],
        'Accuracy': [0.9938, 0.9952, 0.9945, 0.9931, 0.9945],
        'Specificity': [0.9945, 0.9972, 0.9963, 0.9991, 0.9991],
        'MCC': [0.9835, 0.9871, 0.9853, 0.9816, 0.9852],
        'AUC': [0.9998, 0.9999, 0.9999, 0.9999, 0.9994]
    }
}

averages = {metric: [] for metric in data['ArtNouveau']}
overall = {metric: [] for metric in data['ArtNouveau']}

for metric in data['ArtNouveau']:
    for class_name in data:
        avg = sum(data[class_name][metric]) / len(data[class_name][metric])
        averages[metric].append(avg)
    overall_avg = sum(averages[metric]) / len(averages[metric])
    overall[metric] = overall_avg

class_names = list(data.keys())
class_names.append('Overall')
metrics = list(data['ArtNouveau'].keys())

df_data = {class_name: [] for class_name in class_names}
for metric in metrics:
    for i, class_name in enumerate(class_names[:-1]):
        df_data[class_name].append(averages[metric][i])
    df_data['Overall'].append(overall[metric])

df = pd.DataFrame(df_data, index=metrics)

styled_df = df.style.set_table_styles(
    [{
        'selector': 'th',
        'props': [('font-size', '10pt'),
                  ('border', '1px solid black'),
                  ('text-align', 'center'),
                  ('background-color', '#333333'),
                  ('color', 'white')]
    }, {
        'selector': 'td',
        'props': [('font-size', '11pt'),
                  ('border', '1px solid black'),
                  ('text-align', 'center'),
                  ('background-color', '#444444'),
                  ('color', 'white')]
    }]
).set_properties(**{'text-align': 'center'})

styled_df
# Out:
# <style type="text/css">
# #T_405af th {
#   font-size: 10pt;
#   border: 1px solid black;
#   text-align: center;
#   background-color: #333333;
#   color: white;
# }
# #T_405af td {
#   font-size: 11pt;
#   border: 1px solid black;
#   text-align: center;
#   background-color: #444444;
#   color: white;
# }
# #T_405af_row0_col0, #T_405af_row0_col1, #T_405af_row0_col2, #T_405af_row0_col3, #T_405af_row0_col4, #T_405af_row1_col0, #T_405af_row1_col1, #T_405af_row1_col2, #T_405af_row1_col3, #T_405af_row1_col4, #T_405af_row2_col0, #T_405af_row2_col1, #T_405af_row2_col2, #T_405af_row2_col3, #T_405af_row2_col4, #T_405af_row3_col0, #T_405af_row3_col1, #T_405af_row3_col2, #T_405af_row3_col3, #T_405af_row3_col4, #T_405af_row4_col0, #T_405af_row4_col1, #T_405af_row4_col2, #T_405af_row4_col3, #T_405af_row4_col4, #T_405af_row5_col0, #T_405af_row5_col1, #T_405af_row5_col2, #T_405af_row5_col3, #T_405af_row5_col4, #T_405af_row6_col0, #T_405af_row6_col1, #T_405af_row6_col2, #T_405af_row6_col3, #T_405af_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_405af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_405af_level0_col0" class="col_heading level0 col0" >ArtNouveau</th>
#       <th id="T_405af_level0_col1" class="col_heading level0 col1" >Baroque</th>
#       <th id="T_405af_level0_col2" class="col_heading level0 col2" >Gothic</th>
#       <th id="T_405af_level0_col3" class="col_heading level0 col3" >Islamic</th>
#       <th id="T_405af_level0_col4" class="col_heading level0 col4" >Overall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_405af_level0_row0" class="row_heading level0 row0" >Precision</th>
#       <td id="T_405af_row0_col0" class="data row0 col0" >0.982960</td>
#       <td id="T_405af_row0_col1" class="data row0 col1" >0.980980</td>
#       <td id="T_405af_row0_col2" class="data row0 col2" >0.976260</td>
#       <td id="T_405af_row0_col3" class="data row0 col3" >0.991740</td>
#       <td id="T_405af_row0_col4" class="data row0 col4" >0.982985</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row1" class="row_heading level0 row1" >Recall</th>
#       <td id="T_405af_row1_col0" class="data row1 col0" >0.982900</td>
#       <td id="T_405af_row1_col1" class="data row1 col1" >0.967980</td>
#       <td id="T_405af_row1_col2" class="data row1 col2" >0.995600</td>
#       <td id="T_405af_row1_col3" class="data row1 col3" >0.985100</td>
#       <td id="T_405af_row1_col4" class="data row1 col4" >0.982895</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row2" class="row_heading level0 row2" >F1-score</th>
#       <td id="T_405af_row2_col0" class="data row2 col0" >0.982880</td>
#       <td id="T_405af_row2_col1" class="data row2 col1" >0.974380</td>
#       <td id="T_405af_row2_col2" class="data row2 col2" >0.985800</td>
#       <td id="T_405af_row2_col3" class="data row2 col3" >0.988360</td>
#       <td id="T_405af_row2_col4" class="data row2 col4" >0.982855</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row3" class="row_heading level0 row3" >Accuracy</th>
#       <td id="T_405af_row3_col0" class="data row3 col0" >0.991440</td>
#       <td id="T_405af_row3_col1" class="data row3 col1" >0.987300</td>
#       <td id="T_405af_row3_col2" class="data row3 col2" >0.992820</td>
#       <td id="T_405af_row3_col3" class="data row3 col3" >0.994220</td>
#       <td id="T_405af_row3_col4" class="data row3 col4" >0.991445</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row4" class="row_heading level0 row4" >Specificity</th>
#       <td id="T_405af_row4_col0" class="data row4 col0" >0.994280</td>
#       <td id="T_405af_row4_col1" class="data row4 col1" >0.993760</td>
#       <td id="T_405af_row4_col2" class="data row4 col2" >0.991900</td>
#       <td id="T_405af_row4_col3" class="data row4 col3" >0.997240</td>
#       <td id="T_405af_row4_col4" class="data row4 col4" >0.994295</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row5" class="row_heading level0 row5" >MCC</th>
#       <td id="T_405af_row5_col0" class="data row5 col0" >0.977200</td>
#       <td id="T_405af_row5_col1" class="data row5 col1" >0.966000</td>
#       <td id="T_405af_row5_col2" class="data row5 col2" >0.981080</td>
#       <td id="T_405af_row5_col3" class="data row5 col3" >0.984540</td>
#       <td id="T_405af_row5_col4" class="data row5 col4" >0.977205</td>
#     </tr>
#     <tr>
#       <th id="T_405af_level0_row6" class="row_heading level0 row6" >AUC</th>
#       <td id="T_405af_row6_col0" class="data row6 col0" >0.998760</td>
#       <td id="T_405af_row6_col1" class="data row6 col1" >0.998860</td>
#       <td id="T_405af_row6_col2" class="data row6 col2" >0.999500</td>
#       <td id="T_405af_row6_col3" class="data row6 col3" >0.999780</td>
#       <td id="T_405af_row6_col4" class="data row6 col4" >0.999225</td>
#     </tr>
#   </tbody>
# </table>
